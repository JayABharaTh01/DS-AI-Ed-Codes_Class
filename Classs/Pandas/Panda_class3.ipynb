# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###Data preprocessing

# %%
data=pd.read_excel("/content/Sample - Superstore.xls")
data.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
null_data = pd.DataFrame({
    'A': [1, 2, np.nan, 4, 5],
    'B': [6, np.nan, 8, 9, 10],
    'C': [11, 12, 13, np.nan, 15],
    'D': [np.nan, 17, 18, 19, 20],
    'E': [21, 22, 23, 24, np.nan]
})

print("Sample dataset with null values:")
display(null_data)
# Out:
# Sample dataset with null values:
#      A     B     C     D     E
# 0  1.0   6.0  11.0   NaN  21.0
# 1  2.0   NaN  12.0  17.0  22.0
# 2  NaN   8.0  13.0  18.0  23.0
# 3  4.0   9.0   NaN  19.0  24.0
# 4  5.0  10.0  15.0  20.0   NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# null_data['A'].plot(kind='hist', bins=20, title='A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# null_data['B'].plot(kind='hist', bins=20, title='B')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# null_data['C'].plot(kind='hist', bins=20, title='C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# null_data['D'].plot(kind='hist', bins=20, title='D')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
Null_vlaues_present=null_data.isna()
Null_vlaues_present
# Out:
#        A      B      C      D      E
# 0  False  False  False   True  False
# 1  False   True  False  False  False
# 2   True  False  False  False  False
# 3  False  False   True  False  False
# 4  False  False  False  False   True

# %%
Null_vlaues_percentage=null_data.isna().sum()/null_data.shape[0]*100
Null_vlaues_percentage
# Out:
# A    20.0
# B    20.0
# C    20.0
# D    20.0
# E    20.0
# dtype: float64

# %%
#to drop null value in data
Dropnall1=null_data.dropna(axis=1,how='any')
Dropnall1
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
Dropnall2=null_data.dropna(axis=0,how='any')
Dropnall2
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
Dropnall3=null_data.dropna(axis=0,how='all')
Dropnall3
# Out:
#      A     B     C     D     E
# 0  1.0   6.0  11.0   NaN  21.0
# 1  2.0   NaN  12.0  17.0  22.0
# 2  NaN   8.0  13.0  18.0  23.0
# 3  4.0   9.0   NaN  19.0  24.0
# 4  5.0  10.0  15.0  20.0   NaN

# %%
Dropnall4=null_data.dropna(axis=0,how='all')
Dropnall4
# Out:
#      A     B     C     D     E
# 0  1.0   6.0  11.0   NaN  21.0
# 1  2.0   NaN  12.0  17.0  22.0
# 2  NaN   8.0  13.0  18.0  23.0
# 3  4.0   9.0   NaN  19.0  24.0
# 4  5.0  10.0  15.0  20.0   NaN

# %%
fill_null_data=null_data.fillna(100)
print(fill_null_data)
print(null_data)
# Out:
#        A      B      C      D      E
# 0    1.0    6.0   11.0  100.0   21.0
# 1    2.0  100.0   12.0   17.0   22.0
# 2  100.0    8.0   13.0   18.0   23.0
# 3    4.0    9.0  100.0   19.0   24.0
# 4    5.0   10.0   15.0   20.0  100.0
#      A     B     C     D     E
# 0  1.0   6.0  11.0   NaN  21.0
# 1  2.0   NaN  12.0  17.0  22.0
# 2  NaN   8.0  13.0  18.0  23.0
# 3  4.0   9.0   NaN  19.0  24.0
# 4  5.0  10.0  15.0  20.0   NaN

# %%
print(null_data)
fill_null_data1=null_data['C'].fillna(22)
fill_null_data1
# Out:
#      A     B     C     D     E
# 0  1.0   6.0  11.0   NaN  21.0
# 1  2.0   NaN  12.0  17.0  22.0
# 2  NaN   8.0  13.0  18.0  23.0
# 3  4.0   9.0   NaN  19.0  24.0
# 4  5.0  10.0  15.0  20.0   NaN
# 0    11.0
# 1    12.0
# 2    13.0
# 3    22.0
# 4    15.0
# Name: C, dtype: float64

# %%
fill_null_data2=null_data['C'].fillna(null_data['C'].mean())
fill_null_data2
# Out:
# 0    11.00
# 1    12.00
# 2    13.00
# 3    12.75
# 4    15.00
# Name: C, dtype: float64

# %%
print(null_data)
fill_null_data1=null_data[2].fillna(22)
fill_null_data1
# Out:
#      A     B     C     D     E
# 0  1.0   6.0  11.0   NaN  21.0
# 1  2.0   NaN  12.0  17.0  22.0
# 2  NaN   8.0  13.0  18.0  23.0
# 3  4.0   9.0   NaN  19.0  24.0
# 4  5.0  10.0  15.0  20.0   NaN
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ####null value treatment
# data.isna()#to check null vlaues,,
# data.isna().sum()/data.shape[0]*100 #to check null vlaues in %
# data.dropna(axis=1 or 0,how='any or all')# it use only if for 80% of data of row or column is null
# data["varable/title"].fillna(values)# it is not fixed data
# data["varable/title"].fillna(values,inplace=True)# it is fixed data
# data["varable/title"].fillna(data["varable/value"].mean/np.median(),inplace=True)# it is fixed data
# data["varable/title"].fillna(method="ffill")#it is forverd fill not fixed data
# data["varable/title"].fillna(method="bfill",inplace=True)#it is backverd fill fixed data

# %%
##### Null value treatment
  #### i will check null values
  ### Take percentage of null values
  ### confirm the threshold
  ### if it is beyond threshold drop the columns
  ### if it is less than threshold keep the columns
    #### if it is numercial : mean , medain
    #### if it is categorical : mode
    #### if it is data , time basesd : ffill or bfill

# %% [markdown]
# ####Memoey Optimization
#
# data.memory_usage()#
# data["varablr/value"]=data["varablr/value"].astype(np.int8)#it use to srink the size of data
# np.iinfo(np.int8)#use to find range of data type
#
# df.select_dtypes(['int64']).column#

# %% [markdown]
# from sklearn.preprocessing import minmax_scale# it is in bulid lib for min,max in numpy,panda,,,,
# min=MinMaxScaler(),
# min.fit(data),
# min.transform(data),
# min.fit_transform(data),

# %% [markdown]
# ###spacial char:-
# for i in data.columns:
#
#   for j in[",","$"]
#
# data[varable/value].str.replace("sp_char"," ")#it use for replace spacial char

# %% [markdown]
# ### sampling:-
# data.sample()#give sample of data

# %%
### train test split

# %%
market_data=pd.read_csv("/content/market_data.csv")
market_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
market_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
market_data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
market_data.shape
# Out:
# (8523, 12)

# %%
market_data.size
# Out:
# 102276

# %%
market_data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
market_data.isna()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
market_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
Per_null_values=market_data.isna().sum()/market_data.shape[0]*100
Per_null_values
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
Axis_1_drop1=market_data.dropna(axis=1,how='any')
Axis_1_drop1
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0              FDA15          Low Fat         0.016047                  Dairy
# 1              DRC01          Regular         0.019278            Soft Drinks
# 2              FDN15          Low Fat         0.016760                   Meat
# 3              FDX07          Regular         0.000000  Fruits and Vegetables
# 4              NCD19          Low Fat         0.000000              Household
# ...              ...              ...              ...                    ...
# 8518           FDF22          Low Fat         0.056783            Snack Foods
# 8519           FDS36          Regular         0.046982           Baking Goods
# 8520           NCJ29          Low Fat         0.035186     Health and Hygiene
# 8521           FDN46          Regular         0.145221            Snack Foods
# 8522           DRG01          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
Axis_0_drop2=market_data.dropna(axis=0,how='any')
Axis_0_drop2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
Axis_0_drop3=market_data.dropna(axis=0,how='all')
Axis_0_drop3
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
Axis_1_drop4=market_data.dropna(axis=1,how='all')
Axis_1_drop4
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
Fill_null_=market_data.fillna(22)
Fill_null_
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
mean_median_null_value_replace=market_data['Item_Weight'].fillna(market_data['Item_Weight'].mean())
mean_median_null_value_replace
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
List_nullValue_tre1 = Per_null_values[Per_null_values > 30].index
List_nullValue_tre1
# Out:
# Index([], dtype='object')

# %%
List_nullValue_tre2= Per_null_values[Per_null_values < 30].index
List_nullValue_tre2
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
memoory_usage=market_data.memory_usage()
memoory_usage
# Out:
# Index                          132
# Item_Identifier              68184
# Item_Weight                  68184
# Item_Fat_Content             68184
# Item_Visibility              68184
# Item_Type                    68184
# Item_MRP                     68184
# Outlet_Identifier            68184
# Outlet_Establishment_Year    68184
# Outlet_Size                  68184
# Outlet_Location_Type         68184
# Outlet_Type                  68184
# Item_Outlet_Sales            68184
# dtype: int64

# %%
market_data_types=market_data.dtypes
market_data_types
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
memoory_usage_sum=market_data.memory_usage(deep=True).sum()
memoory_usage_sum
# Out:
# np.int64(3695765)

# %%
memoory_usage_sum1=market_data.memory_usage(deep=True).sum()/(1024*1024)
memoory_usage_sum1
# Out:
# np.float64(3.5245561599731445)

# %%
market_data['Item_Visibility']=market_data['Item_Visibility'].astype(np.float16)
market_data['Item_Visibility']
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# 0       0.016052
# 1       0.019272
# 2       0.016754
# 3       0.000000
# 4       0.000000
#           ...
# 8518    0.056793
# 8519    0.046997
# 8520    0.035187
# 8521    0.145264
# 8522    0.044891
# Name: Item_Visibility, Length: 8523, dtype: float16

# %%
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.finfo(np.float32)
# Out:
# finfo(resolution=1e-06, min=-3.4028235e+38, max=3.4028235e+38, dtype=float32)

# %%
#visulization

##type of graph:-
simgle variable:-
1.histogram,
2.bar grap,
3.rug plot,
4.heatmap,
5.coropleth map
multi variable:-
if we draw a stright ling in graph then it is linear plot
6.scatter plot,
7.linear modal Plot,
8.non-linear modal Plot
9.line graph(time series model)(time dependent graph)
10.box plot# based on inter qurtial process
11.violin plot
12.swarm plot
13.
